# %% [markdown]
# # BDCC project - Spark data processing
#
# **[Big Data and Cloud Computing](https://www.dcc.fc.up.pt/~edrdo/aulas/bdcc), Eduardo R. B. Marques, DCC/FCUP**

# %% [markdown]
# ## Spark setup

# %%
def setupSpark():
  # Spark needs to run with Java 8 ... 
  # !pip install -q findspark
  # !apt-get install openjdk-8-jdk-headless > /dev/null
  # !echo 2 | update-alternatives --config java > /dev/null
  # !java -version
  import os, findspark
  os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-8-openjdk-amd64'
  # !echo JAVA_HOME=$JAVA_HOME
  # !pip install -q pyspark
  findspark.init(spark_home='/usr/local/lib/python3.6/dist-packages/pyspark')
  # !pyspark --version

setupSpark()

from pyspark import SparkContext
from pyspark.sql import SparkSession
    
spark = SparkSession\
        .builder\
        .master('local[*]')\
        .getOrCreate()
sc = spark.sparkContext
# Out:
#      |████████████████████████████████| 217.8MB 56kB/s
#      |████████████████████████████████| 204kB 49.9MB/s
#   Building wheel for pyspark (setup.py) ... done
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 2.4.5
#       /_/
#
# Using Scala version 2.11.12, OpenJDK 64-Bit Server VM, 1.8.0_242
# Branch HEAD
# Compiled by user centos on 2020-02-02T19:38:06Z
# Revision cee4ecbb16917fa85f02c635925e2687400aa56b
# Url https://gitbox.apache.org/repos/asf/spark.git
# Type --help for more information.

# %% [markdown]
# ## Parameters

# %%
#@markdown ---
DEBUG = True #@param {type: "boolean"} 
PROJECT_ID = 'cobalt-catalyst-231416'  #@param {type: "string"}
INPUT_BUCKET = 'bdcc1920_project_datasets' #@param {type: "string"}
DATASET = 'tiny2' #@param ["tiny1", "tiny2", "tiny3", "tiny4", "medium1", "medium2", "medium3", "medium4", "large1", "large2", "large3", "large4", "large5"] {allow-input: true}
OUTPUT_BUCKET = 'up201604170' #@param {type: "string"}
OUTPUT_ZIP_FILE = 'output.zip' #@param {type: "string"}
COPY_PARQUET_FILES_TO_OUTPUT_BUCKET = False #@param {type: "boolean"} 
MIN_TF_IDF = 0.1 #@param {type:"slider", min:0, max:1, step:0.05}
SEND_PUBSUB_MESSAGE = True #@param {type: "boolean"} 
PUBSUB_TOPIC = 'new_output' #@param {type: "string"}
#@markdown ---

# %% [markdown]
# ## Authenticate to GCP

# %%
# The authentication method 
def google_colab_authenticate(projectId, keyFile=None, debug=True):  
    import os
    from google.colab import auth
    if keyFile == None:
      keyFile='/content/bdcc-colab.json'
    if os.access(keyFile,os.R_OK):
      if debug:
        print('Using key file "%s"' % keyFile)
      os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '%s' % keyFile
      os.environ['GCP_PROJECT'] = projectId 
      os.environ['GCP_ACCOUNT'] = 'bdcc-colab@' + projectId + '.iam.gserviceaccount.com'
      # !gcloud auth activate-service-account "$GCP_ACCOUNT" --key-file="$GOOGLE_APPLICATION_CREDENTIALS" --project="$GCP_PROJECT"
    else:
      if debug:
        print('No key file given. You may be redirected to the verification code procedure.')
      auth.authenticate_user()
      # !gcloud config set project $projectId
    # !gcloud info | grep -e Account -e Project

# Copy key file from Google Drive if available 
# to a path without spaces (it usually creates problems)
# !test -f "/content/drive/My Drive/bdcc-colab.json" && cp "/content/drive/My Drive/bdcc-colab.json" /content/bdcc-colab.json

google_colab_authenticate(PROJECT_ID)
# Out:
# No key file given. You may be redirected to the verification code procedure.
# Updated property [core/project].
# Account: [tsilvacoelho@gmail.com]
# Project: [cobalt-catalyst-231416]

# %% [markdown]
# ## Transfer dataset files (if necessary) from GCS

# %%
# !test -d $DATASET || gsutil -m cp -r gs://"$INPUT_BUCKET"/"$DATASET" .
# !du --human $DATASET
# Out:
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/._SUCCESS.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00000-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00001-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00002-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00004-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00003-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00005-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/.part-00006-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/_SUCCESS...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00000-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00001-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00002-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00003-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00004-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00005-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/actors.parquet/part-00006-1435610a-affe-4a9c-9fed-0c5dcf7d5885-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/._SUCCESS.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00000-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00001-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00003-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00002-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00004-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00005-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/.part-00006-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/_SUCCESS...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00000-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00001-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00002-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00003-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00004-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00005-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/genres.parquet/part-00006-8bf13184-bfad-43b3-a08b-4ae3ff30a414-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/._SUCCESS.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00000-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00002-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00001-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00003-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00004-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00005-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00006-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00007-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00008-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00009-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00010-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00011-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00012-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00013-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00014-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00015-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00016-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00017-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00018-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00020-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00019-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00021-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00022-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00023-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00024-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00025-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00026-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00027-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00028-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00029-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00030-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00031-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00032-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00033-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00034-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00035-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00036-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00037-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00038-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00039-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00040-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00041-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00042-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00043-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00044-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00045-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00046-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00047-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00048-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00049-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00050-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00051-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00052-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00053-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00054-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00055-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00056-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00057-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00058-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00059-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00060-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00061-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00062-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00063-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00064-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00065-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00066-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00067-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00068-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00069-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00070-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00071-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00072-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00073-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00074-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00075-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00076-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00077-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00079-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00078-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00081-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00080-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00082-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00083-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00084-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00085-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00086-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00087-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00089-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00088-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00090-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00091-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00092-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00093-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00094-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00095-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00096-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00097-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00098-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00099-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00100-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00101-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00102-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00103-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00104-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00105-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00106-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00107-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00108-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00109-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00110-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00111-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00112-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00113-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00115-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00114-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00116-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00117-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00118-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00119-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00120-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00121-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00122-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00123-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00124-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00125-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00126-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00127-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00128-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00129-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00130-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00131-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00132-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00133-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00134-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00135-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00136-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00137-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00138-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00139-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00140-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00141-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00142-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00143-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00144-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00145-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00146-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00147-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00148-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00149-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00150-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00151-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00152-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00153-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00154-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00155-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00156-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00157-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00158-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00159-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00160-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00161-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00162-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00163-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00164-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00165-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00166-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00168-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00167-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00169-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00170-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00171-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00172-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00173-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00174-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00175-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00176-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00177-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00178-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00179-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00180-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00181-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00182-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00183-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00184-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00185-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00186-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00187-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00188-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00189-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00190-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00191-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00192-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00193-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00194-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00196-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00198-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00197-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00195-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/.part-00199-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/_SUCCESS...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00000-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00001-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00002-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00003-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00004-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00005-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00006-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00007-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00008-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00009-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00010-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00011-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00012-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00013-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00014-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00015-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00016-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00017-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00018-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00019-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00020-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00021-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00022-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00023-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00024-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00025-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00026-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00027-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00028-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00029-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00030-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00031-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00032-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00033-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00034-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00035-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00036-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00037-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00038-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00039-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00040-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00041-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00042-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00043-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00044-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00045-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00046-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00047-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00048-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00049-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00050-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00051-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00052-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00053-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00054-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00055-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00056-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00057-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00058-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00059-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00060-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00061-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00062-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00063-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00064-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00065-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00066-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00067-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00068-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00069-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00070-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00071-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00072-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00073-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00074-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00075-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00076-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00077-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00078-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00079-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00080-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00081-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00082-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00083-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00084-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00086-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00085-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00087-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00088-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00089-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00090-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00091-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00092-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00093-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00094-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00095-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00096-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00097-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00098-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00099-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00100-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00101-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00102-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00103-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00104-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00105-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00106-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00107-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00109-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00108-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00110-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00111-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00112-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00113-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00114-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00115-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00116-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00117-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00118-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00119-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00120-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00121-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00122-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00123-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00124-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00125-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00126-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00127-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00128-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00129-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00130-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00131-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00132-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00133-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00134-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00135-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00136-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00137-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00138-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00139-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00140-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00141-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00142-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00143-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00144-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00145-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00146-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00147-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00148-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00149-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00150-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00151-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00152-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00153-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00154-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00155-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00156-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00157-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00158-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00159-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00160-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00162-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00163-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00161-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00164-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00165-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00166-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00167-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00168-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00171-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00170-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00169-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00172-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00173-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00174-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00175-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00176-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00177-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00178-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00179-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00180-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00181-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00182-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00183-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00184-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00185-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00186-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00187-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00188-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00189-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00190-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00191-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00192-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00193-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00194-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00195-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00196-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00197-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00198-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/movies.parquet/part-00199-3e071885-a639-467f-b2db-bea3df9e3b5b-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/._SUCCESS.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00000-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00001-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00002-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00003-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00004-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/.part-00005-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/_SUCCESS...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00000-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00002-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00001-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00003-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00004-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/ratings.parquet/part-00005-ca477b6c-a3b0-406c-b08d-ab64617afd6c-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/._SUCCESS.crc...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/.part-00000-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/.part-00001-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/.part-00002-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/.part-00003-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet.crc...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/_SUCCESS...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/part-00000-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/part-00001-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/part-00002-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet...
# Copying gs://bdcc1920_project_datasets/large3/tags.parquet/part-00003-20583cc4-4aab-4a13-b178-0fe4c4fd2256-c000.snappy.parquet...
# \ [458/458 files][ 17.2 MiB/ 17.2 MiB] 100% Done   3.3 MiB/s ETA 00:00:00
# Operation completed over 458 objects/17.2 MiB.
# 132K	large3/genres.parquet
# 1.7M	large3/movies.parquet
# 672K	large3/actors.parquet
# 15M	large3/ratings.parquet
# 1.3M	large3/tags.parquet
# 19M	large3

# %% [markdown]
# ## Parquet file read/write methods

# %%
def readParquet(file):
    global spark
    if DEBUG:
       print('==> Reading ' + file)
    df = spark.read.parquet(file)
    if DEBUG:
      df.printSchema()
      df.show(10)
    return df
 
def writeParquet(df,path):
    if DEBUG:
        print('==> Writing ' + path)
    # !rm -fr $path
    df.write.parquet(path, mode='overwrite')

# %% [markdown]
# ## Load input dataset from Parquet files

# %%
movies =  readParquet(DATASET + '/movies.parquet')
actors =  readParquet(DATASET + '/actors.parquet')
genres =  readParquet(DATASET + '/genres.parquet')
ratings = readParquet(DATASET + '/ratings.parquet')
tags =    readParquet(DATASET + '/tags.parquet')
# Out:
# ==> Reading large3/movies.parquet
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#
# +-------+--------------------+----+-------+
# |movieId|               title|year| imdbId|
# +-------+--------------------+----+-------+
# | 118946|The Aggression Scale|2012|1816597|
# | 118954|New York Lightboa...|1961|  55227|
# | 118956|   Lines: Horizontal|1962|  56185|
# | 118968|           Amour fou|2014|3003800|
# | 118989|Riderà! (Cuore ma...|1967|  62199|
# | 119029|   Squadra antifurto|1976|  76753|
# | 119039|Squadra antigangs...|1979|  79943|
# | 119041|Agenzia Riccardo ...|1979|  77130|
# | 119049|Delitto a Porta R...|1980|  80606|
# | 119084|           Narcissus|1983| 203725|
# +-------+--------------------+----+-------+
# only showing top 10 rows
#
# ==> Reading large3/actors.parquet
# root
#  |-- movieId: integer (nullable = true)
#  |-- name: string (nullable = true)
#
# +-------+-----------------+
# |movieId|             name|
# +-------+-----------------+
# | 184449|   David Giancola|
# | 184459| Persis Khambatta|
# | 184459|Peggy McIntaggart|
# | 184459| Kathleen Kinmont|
# | 184459|      James Emery|
# | 184475|         Madhavan|
# | 184475|      Delhi Kumar|
# | 184475|          Jyotika|
# | 184475|           Murali|
# | 184491|   Robert Hossein|
# +-------+-----------------+
# only showing top 10 rows
#
# ==> Reading large3/genres.parquet
# root
#  |-- movieId: integer (nullable = true)
#  |-- genre: string (nullable = true)
#
# +-------+-----------+
# |movieId|      genre|
# +-------+-----------+
# | 125289|  Animation|
# | 125289|   Children|
# | 125295|     Action|
# | 125295|   Thriller|
# | 125295|        War|
# | 125297|Documentary|
# | 125301|     Comedy|
# | 125301|    Romance|
# | 125329|     Comedy|
# | 125329|     Horror|
# +-------+-----------+
# only showing top 10 rows
#
# ==> Reading large3/ratings.parquet
# root
#  |-- movieId: integer (nullable = true)
#  |-- userId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#
# +-------+------+------+
# |movieId|userId|rating|
# +-------+------+------+
# |   1449|     1|   4.5|
# |   1590|     1|   2.5|
# |   1591|     1|   1.5|
# |   2840|     1|   3.0|
# |   1221|     3|   4.0|
# |   1645|     3|   4.0|
# |   1825|     3|   3.0|
# |   1985|     3|   2.0|
# |      2|     4|   4.0|
# |     11|     4|   3.5|
# +-------+------+------+
# only showing top 10 rows
#
# ==> Reading large3/tags.parquet
# root
#  |-- movieId: integer (nullable = true)
#  |-- userId: integer (nullable = true)
#  |-- tag: string (nullable = true)
#
# +-------+------+---------------+
# |movieId|userId|            tag|
# +-------+------+---------------+
# |   5491| 73406|     bandleader|
# |   5491| 73406|      biography|
# |   5491| 73406|        pianist|
# |   5495| 73406|            spy|
# |   5500| 73406|       airplane|
# |   5500| 73406|anarchic comedy|
# |   5500| 73406|      autoradio|
# |   5500| 73406|         ballet|
# |   5500| 73406|          beach|
# |   5500| 73406|       bookshop|
# +-------+------+---------------+
# only showing top 10 rows

# %% [markdown]
# ## Calculate aggregate movie data
#
# The aim is to derive a data frame with the same data as __movies__, augmented
# with __numRatings__ and __avgRating__ columns, respectively representing the
# number of ratings and average rating per movie.

# %%
movies.createOrReplaceTempView('movies')
ratings.createOrReplaceTempView('ratings')

if DEBUG:
  print(movies.count())
  movies.printSchema()
  movies.orderBy('movieId').show()

ratings_agg = spark.sql(
    '''
    SELECT movieId,
          COUNT(*) AS numRatings,
          AVG(rating) AS avgRating
    FROM ratings
    GROUP BY movieId
    '''
)
ratings_agg.createOrReplaceTempView('ratings_agg')

if DEBUG:
  print(ratings_agg.count())
  ratings_agg.printSchema()
  ratings_agg.orderBy('movieId').show()

movies_agg = spark.sql(
    '''
    SELECT movieId, title, year, imdbId, 
           ifnull(numRatings, 0) as numRatings,
           ifnull(avgRating, 0.0) as avgRating
    FROM movies LEFT OUTER JOIN ratings_agg USING(movieId)
    ORDER BY movieId
    '''
)
if DEBUG:
  print(movies_agg.count())
  movies_agg.printSchema()
  movies_agg.show()

# no need for these, clean up
spark.catalog.dropGlobalTempView('agg_ratings')
spark.catalog.dropGlobalTempView('ratings')
ratings.unpersist()
# Out:
# 11590
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#
# +-------+--------------------+----+------+
# |movieId|               title|year|imdbId|
# +-------+--------------------+----+------+
# |      2|             Jumanji|1995|113497|
# |      7|             Sabrina|1995|114319|
# |     11|The American Pres...|1995|112346|
# |     17|Sense and Sensibi...|1995|114388|
# |     24|              Powder|1995|114168|
# |     28|          Persuasion|1995|114117|
# |     32|      Twelve Monkeys|1995|114746|
# |     36|    Dead Man Walking|1995|112818|
# |     39|            Clueless|1995|112697|
# |     42|     Dead Presidents|1995|112819|
# |     43|         Restoration|1995|114272|
# |     47|               Se7en|1995|114369|
# |     56|Kids of the Round...|1995|113541|
# |     57|Home for the Holi...|1995|113321|
# |     60|The Indian in the...|1995|113419|
# |     61|      Eye for an Eye|1996|116260|
# |     64|       Two If by Sea|1996|118002|
# |     70| From Dusk Till Dawn|1996|116367|
# |     86|        White Squall|1996|118158|
# |     93| Vampire in Brooklyn|1995|114825|
# +-------+--------------------+----+------+
# only showing top 20 rows
#
# 10777
# root
#  |-- movieId: integer (nullable = true)
#  |-- numRatings: long (nullable = false)
#  |-- avgRating: double (nullable = true)
#
# +-------+----------+------------------+
# |movieId|numRatings|         avgRating|
# +-------+----------+------------------+
# |      2|     27143| 3.246582912721512|
# |      7|     15301| 3.371348277890334|
# |     11|     19669| 3.660277594183741|
# |     17|     24552|3.9501262626262625|
# |     24|      9191|3.1793058426721794|
# |     28|      3424| 4.036360981308412|
# |     32|     54846|3.8901925391095067|
# |     36|     23955| 3.928762262575663|
# |     39|     29422| 3.416287132078037|
# |     42|      2620|3.0482824427480915|
# |     43|      2667|3.4662542182227223|
# |     47|     55240| 4.071687183200579|
# |     56|        83|2.0602409638554215|
# |     57|      2530|3.3223320158102765|
# |     60|      7601|3.0712406262333904|
# |     61|      2465|3.3363083164300202|
# |     64|      2192|2.8378193430656933|
# |     70|     15821| 3.315466784653309|
# |     86|      4606|3.4867564046895354|
# |     93|      2183|  2.51099404489235|
# +-------+----------+------------------+
# only showing top 20 rows
#
# 11590
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#  |-- numRatings: long (nullable = false)
#  |-- avgRating: double (nullable = false)
#
# +-------+--------------------+----+------+----------+------------------+
# |movieId|               title|year|imdbId|numRatings|         avgRating|
# +-------+--------------------+----+------+----------+------------------+
# |      2|             Jumanji|1995|113497|     27143| 3.246582912721512|
# |      7|             Sabrina|1995|114319|     15301| 3.371348277890334|
# |     11|The American Pres...|1995|112346|     19669| 3.660277594183741|
# |     17|Sense and Sensibi...|1995|114388|     24552|3.9501262626262625|
# |     24|              Powder|1995|114168|      9191|3.1793058426721794|
# |     28|          Persuasion|1995|114117|      3424| 4.036360981308412|
# |     32|      Twelve Monkeys|1995|114746|     54846|3.8901925391095067|
# |     36|    Dead Man Walking|1995|112818|     23955| 3.928762262575663|
# |     39|            Clueless|1995|112697|     29422| 3.416287132078037|
# |     42|     Dead Presidents|1995|112819|      2620|3.0482824427480915|
# |     43|         Restoration|1995|114272|      2667|3.4662542182227223|
# |     47|               Se7en|1995|114369|     55240| 4.071687183200579|
# |     56|Kids of the Round...|1995|113541|        83|2.0602409638554215|
# |     57|Home for the Holi...|1995|113321|      2530|3.3223320158102765|
# |     60|The Indian in the...|1995|113419|      7601|3.0712406262333904|
# |     61|      Eye for an Eye|1996|116260|      2465|3.3363083164300202|
# |     64|       Two If by Sea|1996|118002|      2192|2.8378193430656933|
# |     70| From Dusk Till Dawn|1996|116367|     15821| 3.315466784653309|
# |     86|        White Squall|1996|118158|      4606|3.4867564046895354|
# |     93| Vampire in Brooklyn|1995|114825|      2183|  2.51099404489235|
# +-------+--------------------+----+------+----------+------------------+
# only showing top 20 rows
# DataFrame[movieId: int, userId: int, rating: double]

# %% [markdown]
# ## Derive words for TF-IDF processing

# %%
from pyspark.sql import functions as F

# Utility method to explode strings contained in the given field into a 'word' column
def wordDf(df, field):
  wdf = df.withColumn('word',
                      F.explode(F.split(F.lower(F.col(field)),'[ \s\*\+\&\/\%\-\$\#\'\)\(\[\[\],.!?;:\t\n"]+'))).\
                      drop(field)

  return wdf


actor_words = wordDf(actors, 'name')
genre_words = wordDf(genres,'genre')
tag_words = wordDf(tags.drop('userId'), 'tag')
title_words = wordDf(movies.select('movieId','title'), 'title')

all_words = actor_words.union(genre_words)\
                       .union(tag_words)\
                       .union(title_words)\
                       
if DEBUG:
  print(all_words.count())
  all_words.orderBy('movieId','word').show()
# Out:
# 521106
# +-------+----------+
# |movieId|      word|
# +-------+----------+
# |      2|          |
# |      2|          |
# |      2|          |
# |      2|         a|
# |      2|         a|
# |      2|         a|
# |      2|    action|
# |      2|   actress|
# |      2|adaptation|
# |      2|   adapted|
# |      2|   adapted|
# |      2|   adapted|
# |      2| adventure|
# |      2| adventure|
# |      2| adventure|
# |      2|  allsburg|
# |      2|  allsburg|
# |      2|      also|
# |      2|   animals|
# |      2|   animals|
# +-------+----------+
# only showing top 20 rows

# %% [markdown]
# ## Calculate TF-IDF metric (TODO)
#
# The aim is to derive a data frame with __(moviedId, word, tf_idf)__ values
# where the TF-IDF calculation is similar to the [one we discussed before during classes](https://colab.research.google.com/drive/15yMxBf1ltxrIaHCZUqqUWZBm6cqdcErF), i.e., the ${\rm TFIDF}$ term we consider for a movie $m$ in the set of movies $M$ and word $w$ is given by
#
#    $$
#    {\rm TFIDF}(m,w) = {\rm TF}(m,w) \:\times \:{\rm IDF}(w,M)
#    $$
#
# Only TF_IDF values equal or higher than the __MIN\_TF_\_IDF__ threshold should be written to the output files. The standard value to use for __MIN\_TF_\_IDF__ is  __0.1__ but you may adjust this value for testing purposes.

# %%
import math
from pyspark.sql.functions import udf

#Get f table
all_words.createOrReplaceTempView("all_words")
all_words_f = spark.sql("SELECT movieId, word, count(movieId, word) as f FROM all_words Group by movieId, word")

#Get |N|
n_movies = movies.count()

#Get TF
max_f = all_words_f.groupby('movieId').agg({'f': 'max'})
max_f = max_f.withColumnRenamed("max(f)","max_f").withColumnRenamed("movieId","movieId_max")
tfd = max_f.join(all_words_f, max_f.movieId_max == all_words_f.movieId, 'inner').select('movieId', 'max_f', 'word', 'f')
tfd = tfd.withColumn('tf', tfd.f / tfd.max_f).select('movieId','word','tf')

#Get IDF
log = udf(lambda x: math.log(x,2))

idfd = tfd.groupby('word').agg({ 'movieId': 'count'}).withColumnRenamed("count(movieId)","n")
idfd = idfd.withColumn('idf_temp', n_movies / idfd.n)
idfd = idfd.withColumn("idf", log(idfd.idf_temp)).select('word','n','idf')

#Get TF_IDF
tfd = tfd.withColumnRenamed('word','word_tf')
tf_idfd = tfd.join(idfd, tfd.word_tf == idfd.word, 'inner').select('movieId','word','tf','n','idf')
tf_idfd = tf_idfd.withColumn('tf_idf', tf_idfd.tf * tf_idfd.idf)

#Apply MIN_TF_IDF restriction to TF_IDF
tf_idfd = tf_idfd.select('movieId','word','tf_idf').where(tf_idfd.tf_idf >= MIN_TF_IDF)


#Calculate Jackard Index metric
ratings.createOrReplaceTempView("ratings")
ratings_df = spark.sql("SELECT userId, movieId FROM ratings")
tags.createOrReplaceTempView("tags")
tags_df = spark.sql("SELECT DISTINCT userId, movieId FROM tags")
users_df = ratings_df.union(tags_df).distinct()
users_df.createOrReplaceTempView("users_df")

movies_intersection = spark.sql("Select movieId1, movieId2, count(*) as count FROM (SELECT a.userId, a.movieId as movieId1, b.movieId as movieId2 FROM users_df as a JOIN users_df as b on a.userId = b.userId) where movieId1 < movieId2 Group by movieId1, movieId2")
movies_intersection.createOrReplaceTempView("movies_intersection")
movies_m = spark.sql("SELECT movieId, count(*) as count FROM users_df Group by movieId")
movies_m.createOrReplaceTempView("movies_m")
movies_intersection = spark.sql("SELECT movieId1, movieId2, a.count as aggr, b.count as m1 FROM movies_intersection as a JOIN movies_m as b on a.movieId1 = b.movieId")
spark.catalog.dropGlobalTempView('movies_intersection')
movies_intersection.createOrReplaceTempView("movies_intersection")
jackard = spark.sql("SELECT movieId1, movieId2, aggr, m1, b.count as m2 FROM movies_intersection as a JOIN movies_m as b on a.movieId2 = b.movieId")
jackard = jackard.withColumn('ji', jackard.aggr / (jackard.m1 + jackard.m2)).select('movieId1','movieId2','ji')

# %% [markdown]
# ## Write output data to Parquet files and generate ZIP file

# %%
# Clean up first
# !rm -fr "$DATASET"/output 
# !rm -f "$DATASET"/"$OUTPUT_ZIP_FILE"

if DEBUG:
  # !ls -l $DATASET

writeParquet(movies_agg, DATASET + '/output/' + 'movies_agg.parquet')
writeParquet(tf_idfd, DATASET + '/output/' + 'tfidf.parquet')
writeParquet(jackard, DATASET + '/output/' + 'jackard.parquet')

if DEBUG:
  print('Creating ZIP file ...')

# !cd "$DATASET"/output  && zip -9qr ../"$OUTPUT_ZIP_FILE" .

if DEBUG:
  # !ls -l $DATASET "$DATASET"/output
# Out:
# total 72
# drwxr-xr-x 2 root root  4096 Apr 15 21:20 actors.parquet
# drwxr-xr-x 2 root root  4096 Apr 15 21:20 genres.parquet
# drwxr-xr-x 2 root root 53248 Apr 15 21:20 movies.parquet
# drwxr-xr-x 2 root root  4096 Apr 15 21:20 ratings.parquet
# drwxr-xr-x 2 root root  4096 Apr 15 21:20 tags.parquet
# ==> Writing large3/output/movies_agg.parquet
# ==> Writing large3/output/tfidf.parquet
# ==> Writing large3/output/jackard.parquet
# Creating ZIP file ...
# large3:
# total 150112
# drwxr-xr-x 2 root root      4096 Apr 15 21:20 actors.parquet
# drwxr-xr-x 2 root root      4096 Apr 15 21:20 genres.parquet
# drwxr-xr-x 2 root root     53248 Apr 15 21:20 movies.parquet
# drwxr-xr-x 5 root root      4096 Apr 15 21:25 output
# -rw-r--r-- 1 root root 153635318 Apr 15 21:30 output.zip
# drwxr-xr-x 2 root root      4096 Apr 15 21:20 ratings.parquet
# drwxr-xr-x 2 root root      4096 Apr 15 21:20 tags.parquet
#
# large3/output:
# total 148
# drwxr-xr-x 2 root root 49152 Apr 15 21:30 jackard.parquet
# drwxr-xr-x 2 root root 49152 Apr 15 21:23 movies_agg.parquet
# drwxr-xr-x 2 root root 53248 Apr 15 21:24 tfidf.parquet

# %% [markdown]
# ## Copy output ZIP file to output bucket

# %%
! gsutil cp $DATASET/output.zip gs://"$OUTPUT_BUCKET"/"$DATASET"/output.zip
# Out:
# Copying file://large3/output.zip [Content-Type=application/zip]...
# \
# Operation completed over 1 objects/146.5 MiB.

# %% [markdown]
# ## Copy Parquet files to output bucket (optional)

# %%
if COPY_PARQUET_FILES_TO_OUTPUT_BUCKET:
  ! gsutil -m cp -r $DATASET/output/movies_agg.parquet gs://"$OUTPUT_BUCKET"/"$DATASET"/
  ! gsutil -m cp -r $DATASET/output/tfidf.parquet gs://"$OUTPUT_BUCKET"/"$DATASET"/
  ! gsutil -m cp -r $DATASET/output/jackard.parquet gs://"$OUTPUT_BUCKET"/"$DATASET"/

# %% [markdown]
# ## Send PubSub cloud message

# %% [markdown]
# This will trigger the LCF cloud function.

# %%
if SEND_PUBSUB_MESSAGE:
 # !gcloud pubsub topics publish $PUBSUB_TOPIC --message $DATASET
# Out:
# messageIds:
# - '1127329284852086'
